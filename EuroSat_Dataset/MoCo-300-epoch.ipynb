# %% [markdown]
# # **Import Libraries**

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision.datasets import ImageFolder
from torchvision import transforms
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader, random_split, Dataset
import matplotlib.pyplot as plt
from tqdm import tqdm
import os
import copy
import numpy as np

# %%
import os
os.listdir("/kaggle/input")
# Out:
# ['eurosat-dataset']

# %% [markdown]
# # **Set Up**

# %%
# Device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Dataset Path
dataset_path ="/kaggle/input/eurosat-dataset/EuroSAT"

# %%
transform_classifier = transforms.Compose([
    transforms.Resize(72),
    transforms.CenterCrop(64),
    transforms.ToTensor(),
])

# %%
# Load dataset
full_dataset = datasets.ImageFolder(dataset_path, transform=transform_classifier)
num_classes = len(full_dataset.classes)

# Train - Test - Validation
train_size = int(0.7 * len(full_dataset))
val_size = int(0.15 * len(full_dataset))
test_size = len(full_dataset) - train_size - val_size

train_set, val_set, test_set = random_split(full_dataset, [train_size, val_size, test_size])

train_loader = DataLoader(train_set, batch_size=64, shuffle=True, num_workers=2)
val_loader = DataLoader(val_set, batch_size=64, shuffle=False, num_workers=2)
test_loader = DataLoader(test_set, batch_size=64, shuffle=False, num_workers=2)

# %% [markdown]
# # **Load MoCo Encoder**

# %%
class EncoderWrapper(nn.Module):
    def __init__(self, out_dim=128, checkpoint_path=None):
        super().__init__()
        backbone = models.resnet50(weights=None)   # replaces deprecated pretrained=False
        dim_backbone = backbone.fc.in_features
        backbone.fc = nn.Identity()                # backbone outputs 2048-d features
        self.backbone = backbone
        self.encoder = self.backbone               # alias so .encoder works

        # projection head for contrastive pretraining
        self.proj_head = nn.Sequential(
            nn.Linear(dim_backbone, 512),
            nn.ReLU(inplace=True),
            nn.Linear(512, out_dim)
        )

        if checkpoint_path:
            self.load_state_dict(torch.load(checkpoint_path, map_location="cpu"))

    def forward(self, x, proj=True):
        h = self.backbone(x)        # representation (e.g., 2048-d)
        if proj:
            return self.proj_head(h)  # 128-d for contrastive
        return h                      # backbone features for linear eval


# Instantiate and save encoder (inner backbone weights)
moco_encoder = EncoderWrapper(out_dim=128)

# %% [markdown]
# # **MoCo Momentum Encoder + Queue**

# %%
# Momentum encoder setup
query_encoder = EncoderWrapper().to(device)
key_encoder = EncoderWrapper().to(device)

key_encoder.load_state_dict(query_encoder.state_dict())
for param in key_encoder.parameters():
    param.requires_grad = False  # Freeze key encoder

# Momentum update
def momentum_update(query_encoder, key_encoder, m=0.999):
    for param_q, param_k in zip(query_encoder.parameters(), key_encoder.parameters()):
        param_k.data = param_k.data * m + param_q.data * (1. - m)

K = 4096             # queue size
proj_dim = 128  # must match EncoderWrapper(out_dim)
queue = F.normalize(torch.randn(proj_dim, K, device=device), dim=0)  # [128, K]
queue_ptr = 0

@torch.no_grad()
def dequeue_and_enqueue(keys):
    # keys: [N, proj_dim]
    global queue, queue_ptr
    bsz = keys.shape[0]
    ptr = queue_ptr
    end = ptr + bsz
    if end <= K:
        queue[:, ptr:end] = keys.T
    else:
        first = K - ptr
        queue[:, ptr:] = keys[:first].T
        queue[:, :bsz-first] = keys[first:].T
    queue_ptr = (ptr + bsz) % K

# %% [markdown]
# # **MoCo Pretraining Loop**

# %%
# MoCo v2-style augments for EuroSAT (64x64)
moco_transform = transforms.Compose([
    transforms.RandomResizedCrop(64, scale=(0.2, 1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomApply([transforms.ColorJitter(0.4, 0.4, 0.4, 0.1)], p=0.8),
    transforms.RandomGrayscale(p=0.2),
    transforms.RandomApply([transforms.GaussianBlur(kernel_size=9, sigma=(0.1, 2.0))], p=0.5),
    transforms.ToTensor(),
    # Optional but recommended if you’ll ever swap to ImageNet-pretrained encoders:
    # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

class ContrastiveDataset(Dataset):
    def __init__(self, base_dataset):
        self.dataset = base_dataset
    def __getitem__(self, idx):
        x, _ = self.dataset[idx]
        return moco_transform(x), moco_transform(x)
    def __len__(self):
        return len(self.dataset)

# %%
# Path from EuroSAT dataset
data_dir = "/kaggle/input/eurosat-dataset/EuroSAT"  

# Load base dataset (without transform)
base_dataset = ImageFolder(data_dir)

# Wrap with contrastive dataset
contrastive_dataset = ContrastiveDataset(base_dataset)

# DataLoader
contrastive_loader = DataLoader(contrastive_dataset, batch_size=64, shuffle=True, num_workers=2)

# %%
save_path = "/kaggle/working/best_moco_encoder.pth"
best_loss = float('inf')
moco_losses = []  # Track pretraining loss
temperature = 0.07
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(query_encoder.parameters(), lr=3e-4, weight_decay=1e-4)

for epoch in range(300):
    query_encoder.train()
    key_encoder.eval()

    running = 0.0
    for x_q, x_k in contrastive_loader:
        x_q, x_k = x_q.to(device), x_k.to(device)

        # 1) momentum update before key forward
        momentum_update(query_encoder, key_encoder, m=0.999)

        # 2) forward
        q = query_encoder(x_q, proj=True)                 # [N,128]
        with torch.no_grad():
            k = key_encoder(x_k, proj=True)               # [N,128]

        # 3) L2-normalize
        q = F.normalize(q, dim=1)
        k = F.normalize(k, dim=1)
        
        # 4) logits and loss
        l_pos = torch.einsum('nc,nc->n', q, k).unsqueeze(-1)      # [N, 1]
        l_neg = torch.einsum('nc,ck->nk', q, queue)               # [N, K]
        logits = torch.cat([l_pos, l_neg], dim=1) / temperature   # [N, 1+K]
        labels = torch.zeros(logits.size(0), dtype=torch.long, device=device)
        
        loss = criterion(logits, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        running += loss.item()
        
        # 5) enqueue the current keys
        with torch.no_grad():
            dequeue_and_enqueue(k)

    avg_loss = running / len(contrastive_loader)
    moco_losses.append(avg_loss)
    print(f"Epoch {epoch+1}: loss={avg_loss:.4f}")

    if avg_loss < best_loss:
        best_loss = avg_loss
        torch.save(query_encoder.state_dict(), save_path)
        print(f" Saved best at epoch {epoch+1}")

np.savetxt("/kaggle/working/moco_pretraining_loss.txt", np.array(moco_losses))
# Out:
# Epoch 1: loss=6.5069
#  Saved best at epoch 1
# Epoch 2: loss=7.3206
# Epoch 3: loss=7.3622
# Epoch 4: loss=6.5440
# Epoch 5: loss=6.4470
#  Saved best at epoch 5
# Epoch 6: loss=6.7214
# Epoch 7: loss=6.7039
# Epoch 8: loss=6.7912
# Epoch 9: loss=7.2142
# Epoch 10: loss=7.3155
# Epoch 11: loss=7.3524
# Epoch 12: loss=7.4513
# Epoch 13: loss=7.6804
# Epoch 14: loss=7.8943
# Epoch 15: loss=7.9644
# Epoch 16: loss=7.6740
# Epoch 17: loss=7.3922
# Epoch 18: loss=7.6229
# Epoch 19: loss=7.6043
# Epoch 20: loss=7.4447
# Epoch 21: loss=7.5098
# Epoch 22: loss=7.2095
# Epoch 23: loss=7.1904
# Epoch 24: loss=7.2039
# Epoch 25: loss=7.0013
# Epoch 26: loss=7.0268
# Epoch 27: loss=6.9911
# Epoch 28: loss=7.0288
# Epoch 29: loss=6.9350
# Epoch 30: loss=6.9492
# Epoch 31: loss=7.1089
# Epoch 32: loss=7.0005
# Epoch 33: loss=6.9345
# Epoch 34: loss=7.0941
# Epoch 35: loss=7.1230
# Epoch 36: loss=7.1103
# Epoch 37: loss=7.1142
# Epoch 38: loss=7.0785
# Epoch 39: loss=7.1029
# Epoch 40: loss=7.0736
# Epoch 41: loss=7.0558
# Epoch 42: loss=7.0627
# Epoch 43: loss=7.1571
# Epoch 44: loss=7.1451
# Epoch 45: loss=7.1158
# Epoch 46: loss=7.0972
# Epoch 47: loss=7.1454
# Epoch 48: loss=7.1792
# Epoch 49: loss=7.0966
# Epoch 50: loss=7.0699
# Epoch 51: loss=7.1168
# Epoch 52: loss=7.1463
# Epoch 53: loss=7.1519
# Epoch 54: loss=7.1131
# Epoch 55: loss=7.1130
# Epoch 56: loss=7.1398
# Epoch 57: loss=7.1628
# Epoch 58: loss=7.1309
# Epoch 59: loss=7.1522
# Epoch 60: loss=7.1673
# Epoch 61: loss=7.1604
# Epoch 62: loss=7.1428
# Epoch 63: loss=7.1416
# Epoch 64: loss=7.1302
# Epoch 65: loss=7.1037
# Epoch 66: loss=7.1688
# Epoch 67: loss=7.1529
# Epoch 68: loss=7.0823
# Epoch 69: loss=7.1177
# Epoch 70: loss=7.1645
# Epoch 71: loss=7.1586
# Epoch 72: loss=7.1359
# Epoch 73: loss=7.1603
# Epoch 74: loss=7.1358
# Epoch 75: loss=7.1610
# Epoch 76: loss=7.1471
# Epoch 77: loss=7.1347
# Epoch 78: loss=7.1685
# Epoch 79: loss=7.1723
# Epoch 80: loss=7.1292
# Epoch 81: loss=7.1252
# Epoch 82: loss=7.1531
# Epoch 83: loss=7.1381
# Epoch 84: loss=7.1425
# Epoch 85: loss=7.1491
# Epoch 86: loss=7.1299
# Epoch 87: loss=7.1249
# Epoch 88: loss=7.1400
# Epoch 89: loss=7.1421
# Epoch 90: loss=7.1519
# Epoch 91: loss=7.1461
# Epoch 92: loss=7.1203
# Epoch 93: loss=7.1246
# Epoch 94: loss=7.1365
# Epoch 95: loss=7.1211
# Epoch 96: loss=7.1582
# Epoch 97: loss=7.1622
# Epoch 98: loss=7.1062
# Epoch 99: loss=7.1138
# Epoch 100: loss=7.1592
# Epoch 101: loss=7.1254
# Epoch 102: loss=7.1156
# Epoch 103: loss=7.1515
# Epoch 104: loss=7.1216
# Epoch 105: loss=7.1442
# Epoch 106: loss=7.1506
# Epoch 107: loss=7.1262
# Epoch 108: loss=7.1348
# Epoch 109: loss=7.1626
# Epoch 110: loss=7.0998
# Epoch 111: loss=7.1025
# Epoch 112: loss=7.1662
# Epoch 113: loss=7.1101
# Epoch 114: loss=7.1265
# Epoch 115: loss=7.1898
# Epoch 116: loss=7.1230
# Epoch 117: loss=7.0726
# Epoch 118: loss=7.1911
# Epoch 119: loss=7.1792
# Epoch 120: loss=7.0672
# Epoch 121: loss=7.1440
# Epoch 122: loss=7.1446
# Epoch 123: loss=7.0843
# Epoch 124: loss=7.1699
# Epoch 125: loss=7.1473
# Epoch 126: loss=7.0566
# Epoch 127: loss=7.1698
# Epoch 128: loss=7.1949
# Epoch 129: loss=7.0343
# Epoch 130: loss=7.1544
# Epoch 131: loss=7.2128
# Epoch 132: loss=7.0661
# Epoch 133: loss=7.1067
# Epoch 134: loss=7.2337
# Epoch 135: loss=7.0573
# Epoch 136: loss=7.0653
# Epoch 137: loss=7.2479
# Epoch 138: loss=7.0753
# Epoch 139: loss=7.0138
# Epoch 140: loss=7.2658
# Epoch 141: loss=7.1194
# Epoch 142: loss=6.9810
# Epoch 143: loss=7.3065
# Epoch 144: loss=7.2432
# Epoch 145: loss=6.9167
# Epoch 146: loss=7.2102
# Epoch 147: loss=7.2821
# Epoch 148: loss=6.9505
# Epoch 149: loss=7.1754
# Epoch 150: loss=7.3985
# Epoch 151: loss=7.1918
# Epoch 152: loss=6.9765
# Epoch 153: loss=7.2137
# Epoch 154: loss=7.1954
# Epoch 155: loss=6.9983
# Epoch 156: loss=7.2061
# Epoch 157: loss=7.2365
# Epoch 158: loss=7.0139
# Epoch 159: loss=7.1489
# Epoch 160: loss=7.2403
# Epoch 161: loss=7.0420
# Epoch 162: loss=7.1342
# Epoch 163: loss=7.2342
# Epoch 164: loss=7.0699
# Epoch 165: loss=7.1110
# Epoch 166: loss=7.1990
# Epoch 167: loss=7.0282
# Epoch 168: loss=7.1614
# Epoch 169: loss=7.2608
# Epoch 170: loss=7.0603
# Epoch 171: loss=7.0758
# Epoch 172: loss=7.1965
# Epoch 173: loss=7.0777
# Epoch 174: loss=7.1162
# Epoch 175: loss=7.2510
# Epoch 176: loss=7.0880
# Epoch 177: loss=7.1206
# Epoch 178: loss=7.2015
# Epoch 179: loss=7.0471
# Epoch 180: loss=7.1162
# Epoch 181: loss=7.2871
# Epoch 182: loss=7.1117
# Epoch 183: loss=7.0338
# Epoch 184: loss=7.2603
# Epoch 185: loss=7.1359
# Epoch 186: loss=7.0302
# Epoch 187: loss=7.2140
# Epoch 188: loss=7.1433
# Epoch 189: loss=7.0462
# Epoch 190: loss=7.2508
# Epoch 191: loss=7.1614
# Epoch 192: loss=7.0620
# Epoch 193: loss=7.2668
# Epoch 194: loss=7.1959
# Epoch 195: loss=7.0068
# Epoch 196: loss=7.1976
# Epoch 197: loss=7.1950
# Epoch 198: loss=7.0034
# Epoch 199: loss=7.2281
# Epoch 200: loss=7.2774
# Epoch 201: loss=7.0340
# Epoch 202: loss=7.0937
# Epoch 203: loss=7.1431
# Epoch 204: loss=7.0493
# Epoch 205: loss=7.1991
# Epoch 206: loss=7.2564
# Epoch 207: loss=7.0527
# Epoch 208: loss=7.0821
# Epoch 209: loss=7.1648
# Epoch 210: loss=7.0814
# Epoch 211: loss=7.1800
# Epoch 212: loss=7.1307
# Epoch 213: loss=6.9985
# Epoch 214: loss=7.1962
# Epoch 215: loss=7.2075
# Epoch 216: loss=7.0499
# Epoch 217: loss=7.1563
# Epoch 218: loss=7.1427
# Epoch 219: loss=7.0535
# Epoch 220: loss=7.1726
# Epoch 221: loss=7.1411
# Epoch 222: loss=7.0338
# Epoch 223: loss=7.2099
# Epoch 224: loss=7.1967
# Epoch 225: loss=7.0554
# Epoch 226: loss=7.1512
# Epoch 227: loss=7.1411
# Epoch 228: loss=7.0415
# Epoch 229: loss=7.2116
# Epoch 230: loss=7.1633
# Epoch 231: loss=7.0000
# Epoch 232: loss=7.2124
# Epoch 233: loss=7.1870
# Epoch 234: loss=7.0090
# Epoch 235: loss=7.2010
# Epoch 236: loss=7.2007
# Epoch 237: loss=6.9706
# Epoch 238: loss=7.2035
# Epoch 239: loss=7.2451
# Epoch 240: loss=6.9881
# Epoch 241: loss=7.1699
# Epoch 242: loss=7.2842
# Epoch 243: loss=7.0794
# Epoch 244: loss=7.1078
# Epoch 245: loss=7.1819
# Epoch 246: loss=7.0000
# Epoch 247: loss=7.1847
# Epoch 248: loss=7.2411
# Epoch 249: loss=7.0064
# Epoch 250: loss=7.0951
# Epoch 251: loss=7.2738
# Epoch 252: loss=7.1262
# Epoch 253: loss=7.0704
# Epoch 254: loss=7.1502
# Epoch 255: loss=7.0749
# Epoch 256: loss=7.1583
# Epoch 257: loss=7.1921
# Epoch 258: loss=7.0154
# Epoch 259: loss=7.1246
# Epoch 260: loss=7.2595
# Epoch 261: loss=7.1196
# Epoch 262: loss=7.0938
# Epoch 263: loss=7.1449
# Epoch 264: loss=7.0294
# Epoch 265: loss=7.2174
# Epoch 266: loss=7.2406
# Epoch 267: loss=6.9847
# Epoch 268: loss=7.1128
# Epoch 269: loss=7.2478
# Epoch 270: loss=7.0775
# Epoch 271: loss=7.1354
# Epoch 272: loss=7.1960
# Epoch 273: loss=7.0014
# Epoch 274: loss=7.1980
# Epoch 275: loss=7.2432
# Epoch 276: loss=6.9849
# Epoch 277: loss=7.1883
# Epoch 278: loss=7.3056
# Epoch 279: loss=7.0560
# Epoch 280: loss=7.1225
# Epoch 281: loss=7.2704
# Epoch 282: loss=7.0842
# Epoch 283: loss=7.1173
# Epoch 284: loss=7.2319
# Epoch 285: loss=7.0506
# Epoch 286: loss=7.0779
# Epoch 287: loss=7.2599
# Epoch 288: loss=7.1178
# Epoch 289: loss=7.0571
# Epoch 290: loss=7.1782
# Epoch 291: loss=7.1132
# Epoch 292: loss=7.1308
# Epoch 293: loss=7.1602
# Epoch 294: loss=7.0371
# Epoch 295: loss=7.1199
# Epoch 296: loss=7.2120
# Epoch 297: loss=7.0451
# Epoch 298: loss=7.1132
# Epoch 299: loss=7.2060
# Epoch 300: loss=7.1124

# %%
# Plot Pertraining Loss
moco_losses = np.loadtxt("/kaggle/working/moco_pretraining_loss.txt")

plt.figure(figsize=(8, 4))
plt.plot(range(1, len(moco_losses) + 1), moco_losses, marker='o', linestyle='-', color='purple')
plt.title("MoCo Pretraining Loss per Epoch")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Linear Classifier with Frozen MoCo Encoder**

# %%
enc = EncoderWrapper(out_dim=128)
enc.load_state_dict(torch.load("/kaggle/working/best_moco_encoder.pth", map_location=device))
enc.to(device)

class LinearEvalClassifier(nn.Module):
    def __init__(self, encoder, feat_dim=2048, num_classes=10):
        super().__init__()
        # freeze backbone
        for p in encoder.parameters():
            p.requires_grad = False
        self.encoder = encoder
        self.fc = nn.Linear(feat_dim, num_classes)

    def forward(self, x):
        with torch.no_grad():
            feats = self.encoder(x, proj=False)  # backbone features, not projector
        return self.fc(feats)

model = LinearEvalClassifier(enc, feat_dim=2048, num_classes=num_classes).to(device)
optimizer = torch.optim.SGD(model.fc.parameters(), lr=0.1, momentum=0.9, weight_decay=0.0)
criterion = nn.CrossEntropyLoss()


train_losses, val_losses = [], []
train_accs,  val_accs  = [],  []

best_val_loss = float("inf")

epochs = 300

for epoch in range(epochs):
    # Train
    model.train()
    running_loss, correct, total = 0.0, 0, 0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        logits = model(images)
        loss = criterion(logits, labels)

        optimizer.zero_grad(set_to_none=True)
        loss.backward()
        optimizer.step()

        bs = labels.size(0)
        running_loss += loss.item() * bs
        correct += (logits.argmax(1) == labels).sum().item()
        total += bs

    train_losses.append(running_loss / max(1, total))
    train_accs.append(correct / max(1, total))

    # Validation
    model.eval()
    val_running_loss, vcorrect, vtotal = 0.0, 0, 0
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            vlogits = model(images)
            vloss = criterion(vlogits, labels)

            bs = labels.size(0)
            val_running_loss += vloss.item() * bs
            vcorrect += (vlogits.argmax(1) == labels).sum().item()
            vtotal += bs

    val_loss = val_running_loss / max(1, vtotal)
    val_acc  = vcorrect / max(1, vtotal)
    val_losses.append(val_loss)
    val_accs.append(val_acc)

    print(f"[LinearEval] Epoch {epoch+1}/{epochs}  "
          f"TrainLoss {train_losses[-1]:.4f}  TrainAcc {train_accs[-1]*100:.2f}%  "
          f"ValLoss {val_loss:.4f}  ValAcc {val_acc*100:.2f}%")

    
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model.state_dict(), "/kaggle/working/best_classifier.pth")
        print("  Saved best linear classifier")
# Out:
# [LinearEval] Epoch 1/300  TrainLoss 26.9263  TrainAcc 25.90%  ValLoss 25.8207  ValAcc 24.74%
#   Saved best linear classifier
# [LinearEval] Epoch 2/300  TrainLoss 24.5085  TrainAcc 27.71%  ValLoss 31.9771  ValAcc 32.44%
# [LinearEval] Epoch 3/300  TrainLoss 27.0899  TrainAcc 27.76%  ValLoss 22.0937  ValAcc 26.72%
#   Saved best linear classifier
# [LinearEval] Epoch 4/300  TrainLoss 23.5756  TrainAcc 28.99%  ValLoss 31.5576  ValAcc 18.17%
# [LinearEval] Epoch 5/300  TrainLoss 24.4383  TrainAcc 29.58%  ValLoss 29.8975  ValAcc 27.88%
# [LinearEval] Epoch 6/300  TrainLoss 28.3585  TrainAcc 29.12%  ValLoss 11.4697  ValAcc 33.23%
#   Saved best linear classifier
# [LinearEval] Epoch 7/300  TrainLoss 21.7907  TrainAcc 30.40%  ValLoss 21.0645  ValAcc 28.91%
# [LinearEval] Epoch 8/300  TrainLoss 22.5188  TrainAcc 30.18%  ValLoss 26.0583  ValAcc 29.88%
# [LinearEval] Epoch 9/300  TrainLoss 26.8532  TrainAcc 30.39%  ValLoss 42.6726  ValAcc 23.36%
# [LinearEval] Epoch 10/300  TrainLoss 26.1548  TrainAcc 29.67%  ValLoss 19.5201  ValAcc 33.04%
# [LinearEval] Epoch 11/300  TrainLoss 23.5728  TrainAcc 31.02%  ValLoss 14.8838  ValAcc 38.20%
# [LinearEval] Epoch 12/300  TrainLoss 22.9213  TrainAcc 30.70%  ValLoss 13.8061  ValAcc 36.27%
# [LinearEval] Epoch 13/300  TrainLoss 20.6487  TrainAcc 31.62%  ValLoss 21.2862  ValAcc 38.20%
# [LinearEval] Epoch 14/300  TrainLoss 28.3133  TrainAcc 30.62%  ValLoss 33.7995  ValAcc 29.88%
# [LinearEval] Epoch 15/300  TrainLoss 23.2255  TrainAcc 30.99%  ValLoss 20.0129  ValAcc 30.00%
# [LinearEval] Epoch 16/300  TrainLoss 25.7262  TrainAcc 31.01%  ValLoss 37.2806  ValAcc 23.26%
# [LinearEval] Epoch 17/300  TrainLoss 21.4652  TrainAcc 32.35%  ValLoss 28.7088  ValAcc 34.07%
# [LinearEval] Epoch 18/300  TrainLoss 22.1637  TrainAcc 31.06%  ValLoss 22.0979  ValAcc 29.83%
# [LinearEval] Epoch 19/300  TrainLoss 25.7838  TrainAcc 31.32%  ValLoss 24.2463  ValAcc 32.10%
# [LinearEval] Epoch 20/300  TrainLoss 25.7010  TrainAcc 31.02%  ValLoss 14.8896  ValAcc 36.62%
# [LinearEval] Epoch 21/300  TrainLoss 23.2927  TrainAcc 31.81%  ValLoss 22.4846  ValAcc 30.37%
# [LinearEval] Epoch 22/300  TrainLoss 19.6763  TrainAcc 32.46%  ValLoss 16.5882  ValAcc 32.10%
# [LinearEval] Epoch 23/300  TrainLoss 22.8747  TrainAcc 31.91%  ValLoss 20.9374  ValAcc 28.91%
# [LinearEval] Epoch 24/300  TrainLoss 23.4048  TrainAcc 31.66%  ValLoss 22.9930  ValAcc 32.86%
# [LinearEval] Epoch 25/300  TrainLoss 24.3060  TrainAcc 31.31%  ValLoss 28.8759  ValAcc 32.40%
# [LinearEval] Epoch 26/300  TrainLoss 23.4606  TrainAcc 31.96%  ValLoss 17.8322  ValAcc 38.17%
# [LinearEval] Epoch 27/300  TrainLoss 24.1241  TrainAcc 31.85%  ValLoss 13.6818  ValAcc 31.56%
# [LinearEval] Epoch 28/300  TrainLoss 21.4543  TrainAcc 32.71%  ValLoss 31.5848  ValAcc 30.99%
# [LinearEval] Epoch 29/300  TrainLoss 24.0611  TrainAcc 32.48%  ValLoss 19.5172  ValAcc 31.98%
# [LinearEval] Epoch 30/300  TrainLoss 23.1038  TrainAcc 32.67%  ValLoss 18.2187  ValAcc 34.22%
# [LinearEval] Epoch 31/300  TrainLoss 25.4158  TrainAcc 31.92%  ValLoss 15.8134  ValAcc 33.70%
# [LinearEval] Epoch 32/300  TrainLoss 21.5002  TrainAcc 32.62%  ValLoss 27.7974  ValAcc 28.84%
# [LinearEval] Epoch 33/300  TrainLoss 23.3526  TrainAcc 32.37%  ValLoss 10.3210  ValAcc 37.63%
#   Saved best linear classifier
# [LinearEval] Epoch 34/300  TrainLoss 21.5714  TrainAcc 32.82%  ValLoss 23.4738  ValAcc 34.96%
# [LinearEval] Epoch 35/300  TrainLoss 23.8725  TrainAcc 31.94%  ValLoss 29.6254  ValAcc 32.00%
# [LinearEval] Epoch 36/300  TrainLoss 21.6769  TrainAcc 33.40%  ValLoss 22.9480  ValAcc 37.26%
# [LinearEval] Epoch 37/300  TrainLoss 25.7798  TrainAcc 32.10%  ValLoss 20.5483  ValAcc 33.88%
# [LinearEval] Epoch 38/300  TrainLoss 21.9986  TrainAcc 32.69%  ValLoss 37.0665  ValAcc 26.99%
# [LinearEval] Epoch 39/300  TrainLoss 22.8743  TrainAcc 32.49%  ValLoss 23.5358  ValAcc 35.95%
# [LinearEval] Epoch 40/300  TrainLoss 23.4729  TrainAcc 33.04%  ValLoss 31.3450  ValAcc 33.63%
# [LinearEval] Epoch 41/300  TrainLoss 23.8807  TrainAcc 32.91%  ValLoss 17.0648  ValAcc 35.38%
# [LinearEval] Epoch 42/300  TrainLoss 22.3127  TrainAcc 32.96%  ValLoss 21.6761  ValAcc 36.59%
# [LinearEval] Epoch 43/300  TrainLoss 22.7744  TrainAcc 32.57%  ValLoss 27.4947  ValAcc 28.59%
# [LinearEval] Epoch 44/300  TrainLoss 23.2352  TrainAcc 32.62%  ValLoss 26.2012  ValAcc 36.69%
# [LinearEval] Epoch 45/300  TrainLoss 20.2275  TrainAcc 33.49%  ValLoss 20.0841  ValAcc 35.90%
# [LinearEval] Epoch 46/300  TrainLoss 20.7107  TrainAcc 33.21%  ValLoss 17.0424  ValAcc 38.74%
# [LinearEval] Epoch 47/300  TrainLoss 21.7025  TrainAcc 33.29%  ValLoss 22.0896  ValAcc 32.32%
# [LinearEval] Epoch 48/300  TrainLoss 22.2410  TrainAcc 33.39%  ValLoss 23.2701  ValAcc 31.33%
# [LinearEval] Epoch 49/300  TrainLoss 23.4806  TrainAcc 32.59%  ValLoss 17.8512  ValAcc 38.32%
# [LinearEval] Epoch 50/300  TrainLoss 20.5266  TrainAcc 33.96%  ValLoss 16.7586  ValAcc 37.98%
# [LinearEval] Epoch 51/300  TrainLoss 20.4261  TrainAcc 33.86%  ValLoss 39.6293  ValAcc 29.43%
# [LinearEval] Epoch 52/300  TrainLoss 22.6899  TrainAcc 32.97%  ValLoss 28.8795  ValAcc 37.46%
# [LinearEval] Epoch 53/300  TrainLoss 24.7239  TrainAcc 32.68%  ValLoss 16.1468  ValAcc 32.25%
# [LinearEval] Epoch 54/300  TrainLoss 22.9166  TrainAcc 34.07%  ValLoss 15.0618  ValAcc 35.46%
# [LinearEval] Epoch 55/300  TrainLoss 20.6948  TrainAcc 33.26%  ValLoss 31.5494  ValAcc 36.52%
# [LinearEval] Epoch 56/300  TrainLoss 23.1369  TrainAcc 33.25%  ValLoss 23.1258  ValAcc 33.41%
# [LinearEval] Epoch 57/300  TrainLoss 23.0248  TrainAcc 33.24%  ValLoss 27.8791  ValAcc 28.10%
# [LinearEval] Epoch 58/300  TrainLoss 23.7049  TrainAcc 33.25%  ValLoss 18.2425  ValAcc 27.78%
# [LinearEval] Epoch 59/300  TrainLoss 21.5898  TrainAcc 33.69%  ValLoss 28.7727  ValAcc 36.81%
# [LinearEval] Epoch 60/300  TrainLoss 20.2633  TrainAcc 34.25%  ValLoss 15.3584  ValAcc 34.40%
# [LinearEval] Epoch 61/300  TrainLoss 27.0604  TrainAcc 32.54%  ValLoss 13.6334  ValAcc 40.42%
# [LinearEval] Epoch 62/300  TrainLoss 26.4274  TrainAcc 33.08%  ValLoss 29.3651  ValAcc 32.07%
# [LinearEval] Epoch 63/300  TrainLoss 24.5490  TrainAcc 33.36%  ValLoss 16.9344  ValAcc 31.46%
# [LinearEval] Epoch 64/300  TrainLoss 24.7092  TrainAcc 33.27%  ValLoss 15.0237  ValAcc 41.41%
# [LinearEval] Epoch 65/300  TrainLoss 21.7754  TrainAcc 34.03%  ValLoss 23.0631  ValAcc 36.32%
# [LinearEval] Epoch 66/300  TrainLoss 21.7900  TrainAcc 34.30%  ValLoss 21.3393  ValAcc 29.38%
# [LinearEval] Epoch 67/300  TrainLoss 20.3213  TrainAcc 34.11%  ValLoss 20.1184  ValAcc 32.91%
# [LinearEval] Epoch 68/300  TrainLoss 26.1184  TrainAcc 33.06%  ValLoss 15.2629  ValAcc 37.43%
# [LinearEval] Epoch 69/300  TrainLoss 26.0037  TrainAcc 33.95%  ValLoss 15.7677  ValAcc 32.10%
# [LinearEval] Epoch 70/300  TrainLoss 21.0758  TrainAcc 34.05%  ValLoss 18.3373  ValAcc 36.72%
# [LinearEval] Epoch 71/300  TrainLoss 20.9418  TrainAcc 34.85%  ValLoss 23.2405  ValAcc 29.19%
# [LinearEval] Epoch 72/300  TrainLoss 23.4778  TrainAcc 33.78%  ValLoss 18.7131  ValAcc 34.42%
# [LinearEval] Epoch 73/300  TrainLoss 23.6567  TrainAcc 33.93%  ValLoss 18.0417  ValAcc 40.89%
# [LinearEval] Epoch 74/300  TrainLoss 22.3377  TrainAcc 34.92%  ValLoss 34.7809  ValAcc 27.48%
# [LinearEval] Epoch 75/300  TrainLoss 19.8427  TrainAcc 34.42%  ValLoss 18.1922  ValAcc 33.01%
# [LinearEval] Epoch 76/300  TrainLoss 21.0171  TrainAcc 33.93%  ValLoss 21.5792  ValAcc 33.53%
# [LinearEval] Epoch 77/300  TrainLoss 22.9929  TrainAcc 33.59%  ValLoss 24.7408  ValAcc 31.09%
# [LinearEval] Epoch 78/300  TrainLoss 22.3329  TrainAcc 33.74%  ValLoss 21.1462  ValAcc 32.96%
# [LinearEval] Epoch 79/300  TrainLoss 20.6056  TrainAcc 34.95%  ValLoss 14.6697  ValAcc 36.74%
# [LinearEval] Epoch 80/300  TrainLoss 23.4652  TrainAcc 33.97%  ValLoss 17.5506  ValAcc 32.99%
# [LinearEval] Epoch 81/300  TrainLoss 21.9356  TrainAcc 34.72%  ValLoss 15.5671  ValAcc 37.21%
# [LinearEval] Epoch 82/300  TrainLoss 21.9585  TrainAcc 33.59%  ValLoss 28.2133  ValAcc 33.06%
# [LinearEval] Epoch 83/300  TrainLoss 20.5803  TrainAcc 34.62%  ValLoss 19.4637  ValAcc 33.28%
# [LinearEval] Epoch 84/300  TrainLoss 24.1023  TrainAcc 34.26%  ValLoss 37.6011  ValAcc 23.41%
# [LinearEval] Epoch 85/300  TrainLoss 20.2190  TrainAcc 35.16%  ValLoss 17.4987  ValAcc 39.26%
# [LinearEval] Epoch 86/300  TrainLoss 21.5033  TrainAcc 34.31%  ValLoss 28.7336  ValAcc 30.64%
# [LinearEval] Epoch 87/300  TrainLoss 22.6987  TrainAcc 34.16%  ValLoss 22.7852  ValAcc 33.83%
# [LinearEval] Epoch 88/300  TrainLoss 22.2521  TrainAcc 33.97%  ValLoss 21.7420  ValAcc 37.38%
# [LinearEval] Epoch 89/300  TrainLoss 20.4381  TrainAcc 35.06%  ValLoss 17.0015  ValAcc 34.81%
# [LinearEval] Epoch 90/300  TrainLoss 20.6759  TrainAcc 34.74%  ValLoss 13.2959  ValAcc 33.93%
# [LinearEval] Epoch 91/300  TrainLoss 22.9817  TrainAcc 33.83%  ValLoss 20.4632  ValAcc 28.30%
# [LinearEval] Epoch 92/300  TrainLoss 20.3128  TrainAcc 34.99%  ValLoss 11.7268  ValAcc 41.33%
# [LinearEval] Epoch 93/300  TrainLoss 21.1285  TrainAcc 34.15%  ValLoss 14.3672  ValAcc 36.27%
# [LinearEval] Epoch 94/300  TrainLoss 24.5318  TrainAcc 33.51%  ValLoss 36.7514  ValAcc 33.41%
# [LinearEval] Epoch 95/300  TrainLoss 21.2659  TrainAcc 34.42%  ValLoss 20.5532  ValAcc 31.60%
# [LinearEval] Epoch 96/300  TrainLoss 23.4624  TrainAcc 33.94%  ValLoss 17.9371  ValAcc 38.89%
# [LinearEval] Epoch 97/300  TrainLoss 21.8338  TrainAcc 35.01%  ValLoss 21.3994  ValAcc 33.11%
# [LinearEval] Epoch 98/300  TrainLoss 23.5765  TrainAcc 33.77%  ValLoss 31.2013  ValAcc 35.28%
# [LinearEval] Epoch 99/300  TrainLoss 19.8067  TrainAcc 35.35%  ValLoss 47.0380  ValAcc 25.53%
# [LinearEval] Epoch 100/300  TrainLoss 20.2633  TrainAcc 34.68%  ValLoss 24.6374  ValAcc 31.65%
# [LinearEval] Epoch 101/300  TrainLoss 21.6185  TrainAcc 34.35%  ValLoss 18.8704  ValAcc 37.48%
# [LinearEval] Epoch 102/300  TrainLoss 22.4982  TrainAcc 34.15%  ValLoss 27.1885  ValAcc 36.59%
# [LinearEval] Epoch 103/300  TrainLoss 20.8230  TrainAcc 35.11%  ValLoss 35.7880  ValAcc 34.54%
# [LinearEval] Epoch 104/300  TrainLoss 21.5857  TrainAcc 35.08%  ValLoss 19.9842  ValAcc 36.77%
# [LinearEval] Epoch 105/300  TrainLoss 21.8779  TrainAcc 34.29%  ValLoss 25.9155  ValAcc 38.27%
# [LinearEval] Epoch 106/300  TrainLoss 25.0672  TrainAcc 34.52%  ValLoss 17.5465  ValAcc 37.53%
# [LinearEval] Epoch 107/300  TrainLoss 17.9954  TrainAcc 35.70%  ValLoss 9.9706  ValAcc 38.02%
#   Saved best linear classifier
# [LinearEval] Epoch 108/300  TrainLoss 21.5787  TrainAcc 35.12%  ValLoss 15.8219  ValAcc 41.21%
# [LinearEval] Epoch 109/300  TrainLoss 20.2254  TrainAcc 35.20%  ValLoss 15.3292  ValAcc 34.15%
# [LinearEval] Epoch 110/300  TrainLoss 20.9649  TrainAcc 34.81%  ValLoss 14.1545  ValAcc 39.90%
# [LinearEval] Epoch 111/300  TrainLoss 21.2651  TrainAcc 35.47%  ValLoss 14.5935  ValAcc 31.58%
# [LinearEval] Epoch 112/300  TrainLoss 21.1765  TrainAcc 34.68%  ValLoss 15.2439  ValAcc 38.35%
# [LinearEval] Epoch 113/300  TrainLoss 21.0637  TrainAcc 34.69%  ValLoss 19.8558  ValAcc 36.77%
# [LinearEval] Epoch 114/300  TrainLoss 20.5200  TrainAcc 35.17%  ValLoss 27.8668  ValAcc 33.09%
# [LinearEval] Epoch 115/300  TrainLoss 25.0579  TrainAcc 34.46%  ValLoss 13.1725  ValAcc 42.84%
# [LinearEval] Epoch 116/300  TrainLoss 22.7793  TrainAcc 35.29%  ValLoss 17.1578  ValAcc 36.79%
# [LinearEval] Epoch 117/300  TrainLoss 19.5118  TrainAcc 35.52%  ValLoss 16.9973  ValAcc 34.72%
# [LinearEval] Epoch 118/300  TrainLoss 21.3022  TrainAcc 34.69%  ValLoss 19.6995  ValAcc 32.20%
# [LinearEval] Epoch 119/300  TrainLoss 23.7960  TrainAcc 33.98%  ValLoss 11.9794  ValAcc 37.26%
# [LinearEval] Epoch 120/300  TrainLoss 19.2806  TrainAcc 35.61%  ValLoss 12.7904  ValAcc 39.83%
# [LinearEval] Epoch 121/300  TrainLoss 19.3564  TrainAcc 35.08%  ValLoss 24.7126  ValAcc 37.85%
# [LinearEval] Epoch 122/300  TrainLoss 21.2416  TrainAcc 34.89%  ValLoss 12.3555  ValAcc 38.17%
# [LinearEval] Epoch 123/300  TrainLoss 23.6307  TrainAcc 35.41%  ValLoss 36.6005  ValAcc 32.37%
# [LinearEval] Epoch 124/300  TrainLoss 26.8035  TrainAcc 34.16%  ValLoss 16.1608  ValAcc 36.47%
# [LinearEval] Epoch 125/300  TrainLoss 24.3456  TrainAcc 34.94%  ValLoss 19.8075  ValAcc 40.12%
# [LinearEval] Epoch 126/300  TrainLoss 18.9980  TrainAcc 35.21%  ValLoss 15.9714  ValAcc 36.15%
# [LinearEval] Epoch 127/300  TrainLoss 21.8553  TrainAcc 35.22%  ValLoss 27.5973  ValAcc 30.00%
# [LinearEval] Epoch 128/300  TrainLoss 20.9440  TrainAcc 34.90%  ValLoss 13.9121  ValAcc 34.47%
# [LinearEval] Epoch 129/300  TrainLoss 19.8032  TrainAcc 34.97%  ValLoss 14.0034  ValAcc 35.06%
# [LinearEval] Epoch 130/300  TrainLoss 19.7778  TrainAcc 36.10%  ValLoss 14.9475  ValAcc 31.46%
# [LinearEval] Epoch 131/300  TrainLoss 21.4301  TrainAcc 35.65%  ValLoss 13.4840  ValAcc 40.35%
# [LinearEval] Epoch 132/300  TrainLoss 22.2444  TrainAcc 34.63%  ValLoss 18.7970  ValAcc 42.79%
# [LinearEval] Epoch 133/300  TrainLoss 20.5026  TrainAcc 34.86%  ValLoss 17.0249  ValAcc 34.62%
# [LinearEval] Epoch 134/300  TrainLoss 22.4420  TrainAcc 35.35%  ValLoss 50.0153  ValAcc 39.31%
# [LinearEval] Epoch 135/300  TrainLoss 20.7461  TrainAcc 35.07%  ValLoss 27.7893  ValAcc 39.14%
# [LinearEval] Epoch 136/300  TrainLoss 20.7494  TrainAcc 35.54%  ValLoss 24.0084  ValAcc 33.78%
# [LinearEval] Epoch 137/300  TrainLoss 20.6363  TrainAcc 35.26%  ValLoss 14.4049  ValAcc 37.95%
# [LinearEval] Epoch 138/300  TrainLoss 21.0665  TrainAcc 34.89%  ValLoss 14.8085  ValAcc 34.62%
# [LinearEval] Epoch 139/300  TrainLoss 22.0712  TrainAcc 34.46%  ValLoss 27.5540  ValAcc 34.99%
# [LinearEval] Epoch 140/300  TrainLoss 24.8448  TrainAcc 34.63%  ValLoss 24.4017  ValAcc 38.27%
# [LinearEval] Epoch 141/300  TrainLoss 22.5084  TrainAcc 34.62%  ValLoss 15.9761  ValAcc 37.46%
# [LinearEval] Epoch 142/300  TrainLoss 25.7880  TrainAcc 34.89%  ValLoss 21.1583  ValAcc 42.20%
# [LinearEval] Epoch 143/300  TrainLoss 19.8589  TrainAcc 35.94%  ValLoss 18.4067  ValAcc 33.90%
# [LinearEval] Epoch 144/300  TrainLoss 20.1151  TrainAcc 35.90%  ValLoss 33.5023  ValAcc 30.02%
# [LinearEval] Epoch 145/300  TrainLoss 23.3903  TrainAcc 34.37%  ValLoss 29.6619  ValAcc 34.44%
# [LinearEval] Epoch 146/300  TrainLoss 21.1930  TrainAcc 35.54%  ValLoss 31.4807  ValAcc 32.00%
# [LinearEval] Epoch 147/300  TrainLoss 20.2068  TrainAcc 35.81%  ValLoss 42.1814  ValAcc 33.16%
# [LinearEval] Epoch 148/300  TrainLoss 19.8516  TrainAcc 36.22%  ValLoss 20.7217  ValAcc 38.30%
# [LinearEval] Epoch 149/300  TrainLoss 22.2545  TrainAcc 35.54%  ValLoss 16.5201  ValAcc 35.85%
# [LinearEval] Epoch 150/300  TrainLoss 24.3999  TrainAcc 35.62%  ValLoss 19.7786  ValAcc 34.67%
# [LinearEval] Epoch 151/300  TrainLoss 21.6829  TrainAcc 35.81%  ValLoss 24.7776  ValAcc 36.20%
# [LinearEval] Epoch 152/300  TrainLoss 24.3536  TrainAcc 34.73%  ValLoss 17.6794  ValAcc 38.15%
# [LinearEval] Epoch 153/300  TrainLoss 19.2696  TrainAcc 35.92%  ValLoss 21.2602  ValAcc 34.89%
# [LinearEval] Epoch 154/300  TrainLoss 20.5850  TrainAcc 35.55%  ValLoss 20.6192  ValAcc 33.41%
# [LinearEval] Epoch 155/300  TrainLoss 21.3938  TrainAcc 35.81%  ValLoss 28.4324  ValAcc 30.89%
# [LinearEval] Epoch 156/300  TrainLoss 21.2181  TrainAcc 35.81%  ValLoss 16.4245  ValAcc 32.59%
# [LinearEval] Epoch 157/300  TrainLoss 19.4286  TrainAcc 35.70%  ValLoss 24.3281  ValAcc 35.04%
# [LinearEval] Epoch 158/300  TrainLoss 21.4797  TrainAcc 35.83%  ValLoss 16.4779  ValAcc 34.62%
# [LinearEval] Epoch 159/300  TrainLoss 20.4800  TrainAcc 35.96%  ValLoss 17.8502  ValAcc 36.30%
# [LinearEval] Epoch 160/300  TrainLoss 20.9968  TrainAcc 35.48%  ValLoss 18.9653  ValAcc 35.98%
# [LinearEval] Epoch 161/300  TrainLoss 24.9986  TrainAcc 35.54%  ValLoss 17.3493  ValAcc 38.30%
# [LinearEval] Epoch 162/300  TrainLoss 19.6261  TrainAcc 36.84%  ValLoss 35.6429  ValAcc 22.96%
# [LinearEval] Epoch 163/300  TrainLoss 22.0754  TrainAcc 35.86%  ValLoss 18.5149  ValAcc 37.78%
# [LinearEval] Epoch 164/300  TrainLoss 24.3890  TrainAcc 34.91%  ValLoss 22.4740  ValAcc 36.91%
# [LinearEval] Epoch 165/300  TrainLoss 24.1021  TrainAcc 34.80%  ValLoss 27.6429  ValAcc 36.00%
# [LinearEval] Epoch 166/300  TrainLoss 25.3512  TrainAcc 34.75%  ValLoss 22.0769  ValAcc 36.49%
# [LinearEval] Epoch 167/300  TrainLoss 25.5327  TrainAcc 35.66%  ValLoss 18.3006  ValAcc 37.83%
# [LinearEval] Epoch 168/300  TrainLoss 20.8792  TrainAcc 35.73%  ValLoss 46.3169  ValAcc 33.53%
# [LinearEval] Epoch 169/300  TrainLoss 18.7658  TrainAcc 36.31%  ValLoss 26.9549  ValAcc 32.32%
# [LinearEval] Epoch 170/300  TrainLoss 19.7051  TrainAcc 36.02%  ValLoss 19.5123  ValAcc 39.09%
# [LinearEval] Epoch 171/300  TrainLoss 20.0575  TrainAcc 36.24%  ValLoss 18.5475  ValAcc 34.57%
# [LinearEval] Epoch 172/300  TrainLoss 20.1529  TrainAcc 35.63%  ValLoss 21.3140  ValAcc 32.27%
# [LinearEval] Epoch 173/300  TrainLoss 21.4102  TrainAcc 36.07%  ValLoss 27.2371  ValAcc 38.37%
# [LinearEval] Epoch 174/300  TrainLoss 22.7261  TrainAcc 34.90%  ValLoss 17.6172  ValAcc 42.17%
# [LinearEval] Epoch 175/300  TrainLoss 24.2154  TrainAcc 34.28%  ValLoss 18.1331  ValAcc 36.37%
# [LinearEval] Epoch 176/300  TrainLoss 20.1477  TrainAcc 36.11%  ValLoss 19.0181  ValAcc 36.57%
# [LinearEval] Epoch 177/300  TrainLoss 23.9231  TrainAcc 35.13%  ValLoss 12.5589  ValAcc 41.98%
# [LinearEval] Epoch 178/300  TrainLoss 20.2946  TrainAcc 36.53%  ValLoss 17.0033  ValAcc 37.28%
# [LinearEval] Epoch 179/300  TrainLoss 20.9553  TrainAcc 35.85%  ValLoss 21.6275  ValAcc 32.02%
# [LinearEval] Epoch 180/300  TrainLoss 19.7788  TrainAcc 36.30%  ValLoss 8.6454  ValAcc 38.84%
#   Saved best linear classifier
# [LinearEval] Epoch 181/300  TrainLoss 21.8633  TrainAcc 35.30%  ValLoss 16.4984  ValAcc 39.98%
# [LinearEval] Epoch 182/300  TrainLoss 24.3323  TrainAcc 34.62%  ValLoss 21.8741  ValAcc 36.77%
# [LinearEval] Epoch 183/300  TrainLoss 20.9411  TrainAcc 36.02%  ValLoss 22.4959  ValAcc 33.16%
# [LinearEval] Epoch 184/300  TrainLoss 23.0421  TrainAcc 36.20%  ValLoss 13.3437  ValAcc 42.44%
# [LinearEval] Epoch 185/300  TrainLoss 23.0113  TrainAcc 34.97%  ValLoss 24.7613  ValAcc 30.17%
# [LinearEval] Epoch 186/300  TrainLoss 20.8728  TrainAcc 35.89%  ValLoss 16.4471  ValAcc 35.09%
# [LinearEval] Epoch 187/300  TrainLoss 21.0883  TrainAcc 36.34%  ValLoss 21.6482  ValAcc 35.14%
# [LinearEval] Epoch 188/300  TrainLoss 22.1333  TrainAcc 35.89%  ValLoss 17.0307  ValAcc 38.52%
# [LinearEval] Epoch 189/300  TrainLoss 22.2363  TrainAcc 36.06%  ValLoss 29.1435  ValAcc 41.43%
# [LinearEval] Epoch 190/300  TrainLoss 23.3399  TrainAcc 35.46%  ValLoss 23.3773  ValAcc 40.42%
# [LinearEval] Epoch 191/300  TrainLoss 19.7061  TrainAcc 36.37%  ValLoss 29.1600  ValAcc 36.30%
# [LinearEval] Epoch 192/300  TrainLoss 25.3096  TrainAcc 35.09%  ValLoss 16.1254  ValAcc 39.36%
# [LinearEval] Epoch 193/300  TrainLoss 21.4850  TrainAcc 35.54%  ValLoss 16.3682  ValAcc 38.67%
# [LinearEval] Epoch 194/300  TrainLoss 20.3122  TrainAcc 36.15%  ValLoss 16.4457  ValAcc 41.90%
# [LinearEval] Epoch 195/300  TrainLoss 21.0251  TrainAcc 36.13%  ValLoss 15.4219  ValAcc 40.22%
# [LinearEval] Epoch 196/300  TrainLoss 22.6711  TrainAcc 35.44%  ValLoss 14.8992  ValAcc 41.33%
# [LinearEval] Epoch 197/300  TrainLoss 22.5328  TrainAcc 35.51%  ValLoss 19.6183  ValAcc 39.28%
# [LinearEval] Epoch 198/300  TrainLoss 19.2899  TrainAcc 36.67%  ValLoss 32.3601  ValAcc 40.07%
# [LinearEval] Epoch 199/300  TrainLoss 21.3747  TrainAcc 36.34%  ValLoss 15.2209  ValAcc 41.53%
# [LinearEval] Epoch 200/300  TrainLoss 22.2422  TrainAcc 36.10%  ValLoss 34.4975  ValAcc 30.05%
# [LinearEval] Epoch 201/300  TrainLoss 20.3317  TrainAcc 36.44%  ValLoss 22.8287  ValAcc 40.37%
# [LinearEval] Epoch 202/300  TrainLoss 19.8389  TrainAcc 36.84%  ValLoss 29.8381  ValAcc 37.51%
# [LinearEval] Epoch 203/300  TrainLoss 22.2409  TrainAcc 36.12%  ValLoss 26.0604  ValAcc 41.28%
# [LinearEval] Epoch 204/300  TrainLoss 22.2760  TrainAcc 35.24%  ValLoss 20.4499  ValAcc 39.11%
# [LinearEval] Epoch 205/300  TrainLoss 20.9807  TrainAcc 36.53%  ValLoss 29.5979  ValAcc 32.17%
# [LinearEval] Epoch 206/300  TrainLoss 20.1366  TrainAcc 36.58%  ValLoss 10.3971  ValAcc 41.98%
# [LinearEval] Epoch 207/300  TrainLoss 22.2291  TrainAcc 35.54%  ValLoss 19.5417  ValAcc 39.38%
# [LinearEval] Epoch 208/300  TrainLoss 20.9793  TrainAcc 37.05%  ValLoss 22.4520  ValAcc 38.37%
# [LinearEval] Epoch 209/300  TrainLoss 23.2058  TrainAcc 36.25%  ValLoss 16.2444  ValAcc 32.67%
# [LinearEval] Epoch 210/300  TrainLoss 19.4358  TrainAcc 36.46%  ValLoss 15.3358  ValAcc 41.56%
# [LinearEval] Epoch 211/300  TrainLoss 18.7975  TrainAcc 36.86%  ValLoss 21.9464  ValAcc 37.98%
# [LinearEval] Epoch 212/300  TrainLoss 21.0010  TrainAcc 36.24%  ValLoss 17.4197  ValAcc 32.30%
# [LinearEval] Epoch 213/300  TrainLoss 19.9840  TrainAcc 36.60%  ValLoss 20.0927  ValAcc 29.09%
# [LinearEval] Epoch 214/300  TrainLoss 19.8309  TrainAcc 36.31%  ValLoss 30.3118  ValAcc 28.12%
# [LinearEval] Epoch 215/300  TrainLoss 21.9471  TrainAcc 36.05%  ValLoss 17.2404  ValAcc 35.38%
# [LinearEval] Epoch 216/300  TrainLoss 22.9900  TrainAcc 35.87%  ValLoss 13.3309  ValAcc 43.63%
# [LinearEval] Epoch 217/300  TrainLoss 26.1550  TrainAcc 34.50%  ValLoss 25.2463  ValAcc 39.41%
# [LinearEval] Epoch 218/300  TrainLoss 20.8165  TrainAcc 36.65%  ValLoss 19.4741  ValAcc 37.41%
# [LinearEval] Epoch 219/300  TrainLoss 21.3354  TrainAcc 36.30%  ValLoss 15.9066  ValAcc 36.67%
# [LinearEval] Epoch 220/300  TrainLoss 22.9782  TrainAcc 35.99%  ValLoss 15.9060  ValAcc 42.69%
# [LinearEval] Epoch 221/300  TrainLoss 21.0363  TrainAcc 35.73%  ValLoss 20.8114  ValAcc 35.04%
# [LinearEval] Epoch 222/300  TrainLoss 23.0772  TrainAcc 35.99%  ValLoss 13.3755  ValAcc 36.15%
# [LinearEval] Epoch 223/300  TrainLoss 20.3316  TrainAcc 36.47%  ValLoss 27.9973  ValAcc 32.37%
# [LinearEval] Epoch 224/300  TrainLoss 21.3796  TrainAcc 36.65%  ValLoss 22.0198  ValAcc 33.70%
# [LinearEval] Epoch 225/300  TrainLoss 19.1017  TrainAcc 37.15%  ValLoss 19.4485  ValAcc 34.12%
# [LinearEval] Epoch 226/300  TrainLoss 23.9979  TrainAcc 35.70%  ValLoss 34.2595  ValAcc 36.69%
# [LinearEval] Epoch 227/300  TrainLoss 22.0576  TrainAcc 35.87%  ValLoss 19.8298  ValAcc 41.21%
# [LinearEval] Epoch 228/300  TrainLoss 21.6774  TrainAcc 36.44%  ValLoss 23.9200  ValAcc 32.64%
# [LinearEval] Epoch 229/300  TrainLoss 19.2544  TrainAcc 36.52%  ValLoss 40.7728  ValAcc 35.68%
# [LinearEval] Epoch 230/300  TrainLoss 19.4866  TrainAcc 37.05%  ValLoss 27.7656  ValAcc 33.98%
# [LinearEval] Epoch 231/300  TrainLoss 19.1625  TrainAcc 36.76%  ValLoss 34.9497  ValAcc 32.00%
# [LinearEval] Epoch 232/300  TrainLoss 21.2008  TrainAcc 36.32%  ValLoss 18.9955  ValAcc 39.60%
# [LinearEval] Epoch 233/300  TrainLoss 22.9964  TrainAcc 36.39%  ValLoss 12.5185  ValAcc 39.73%
# [LinearEval] Epoch 234/300  TrainLoss 18.5229  TrainAcc 37.71%  ValLoss 18.3955  ValAcc 35.90%
# [LinearEval] Epoch 235/300  TrainLoss 23.1060  TrainAcc 36.51%  ValLoss 25.6923  ValAcc 37.70%
# [LinearEval] Epoch 236/300  TrainLoss 26.1966  TrainAcc 35.74%  ValLoss 15.3785  ValAcc 42.72%
# [LinearEval] Epoch 237/300  TrainLoss 22.7058  TrainAcc 36.04%  ValLoss 25.7129  ValAcc 31.21%
# [LinearEval] Epoch 238/300  TrainLoss 20.0885  TrainAcc 36.78%  ValLoss 21.7935  ValAcc 38.47%
# [LinearEval] Epoch 239/300  TrainLoss 20.5915  TrainAcc 36.60%  ValLoss 20.4819  ValAcc 39.41%
# [LinearEval] Epoch 240/300  TrainLoss 20.0664  TrainAcc 37.26%  ValLoss 22.7945  ValAcc 37.56%
# [LinearEval] Epoch 241/300  TrainLoss 19.5522  TrainAcc 36.70%  ValLoss 27.2422  ValAcc 35.63%
# [LinearEval] Epoch 242/300  TrainLoss 20.7236  TrainAcc 36.48%  ValLoss 20.2942  ValAcc 37.68%
# [LinearEval] Epoch 243/300  TrainLoss 20.0492  TrainAcc 36.93%  ValLoss 28.6395  ValAcc 31.38%
# [LinearEval] Epoch 244/300  TrainLoss 19.5391  TrainAcc 36.68%  ValLoss 27.0816  ValAcc 40.42%
# [LinearEval] Epoch 245/300  TrainLoss 18.9351  TrainAcc 37.04%  ValLoss 17.6667  ValAcc 36.35%
# [LinearEval] Epoch 246/300  TrainLoss 18.9712  TrainAcc 37.08%  ValLoss 19.2351  ValAcc 35.58%
# [LinearEval] Epoch 247/300  TrainLoss 20.8605  TrainAcc 36.24%  ValLoss 18.9508  ValAcc 38.81%
# [LinearEval] Epoch 248/300  TrainLoss 20.3288  TrainAcc 36.60%  ValLoss 12.4691  ValAcc 42.67%
# [LinearEval] Epoch 249/300  TrainLoss 22.4329  TrainAcc 35.96%  ValLoss 17.1706  ValAcc 40.59%
# [LinearEval] Epoch 250/300  TrainLoss 19.5397  TrainAcc 37.49%  ValLoss 24.4701  ValAcc 36.52%
# [LinearEval] Epoch 251/300  TrainLoss 18.9491  TrainAcc 36.72%  ValLoss 37.1326  ValAcc 31.56%
# [LinearEval] Epoch 252/300  TrainLoss 21.0579  TrainAcc 36.99%  ValLoss 41.2737  ValAcc 30.96%
# [LinearEval] Epoch 253/300  TrainLoss 20.7744  TrainAcc 36.70%  ValLoss 26.1538  ValAcc 29.43%
# [LinearEval] Epoch 254/300  TrainLoss 21.3891  TrainAcc 36.02%  ValLoss 26.5789  ValAcc 34.96%
# [LinearEval] Epoch 255/300  TrainLoss 21.1214  TrainAcc 36.83%  ValLoss 35.9232  ValAcc 27.60%
# [LinearEval] Epoch 256/300  TrainLoss 18.9796  TrainAcc 37.30%  ValLoss 14.0708  ValAcc 40.89%
# [LinearEval] Epoch 257/300  TrainLoss 21.9485  TrainAcc 36.21%  ValLoss 15.7776  ValAcc 35.63%
# [LinearEval] Epoch 258/300  TrainLoss 18.3374  TrainAcc 36.92%  ValLoss 14.2522  ValAcc 35.16%
# [LinearEval] Epoch 259/300  TrainLoss 20.4879  TrainAcc 37.15%  ValLoss 30.7672  ValAcc 36.77%
# [LinearEval] Epoch 260/300  TrainLoss 19.4337  TrainAcc 36.75%  ValLoss 21.3343  ValAcc 40.30%
# [LinearEval] Epoch 261/300  TrainLoss 23.4106  TrainAcc 36.60%  ValLoss 16.8015  ValAcc 34.30%
# [LinearEval] Epoch 262/300  TrainLoss 20.4059  TrainAcc 36.93%  ValLoss 22.3872  ValAcc 36.15%
# [LinearEval] Epoch 263/300  TrainLoss 22.3960  TrainAcc 35.81%  ValLoss 26.8571  ValAcc 33.80%
# [LinearEval] Epoch 264/300  TrainLoss 20.8915  TrainAcc 36.69%  ValLoss 25.6218  ValAcc 37.85%
# [LinearEval] Epoch 265/300  TrainLoss 20.3516  TrainAcc 36.82%  ValLoss 22.4189  ValAcc 38.25%
# [LinearEval] Epoch 266/300  TrainLoss 19.4295  TrainAcc 37.61%  ValLoss 17.2162  ValAcc 35.14%
# [LinearEval] Epoch 267/300  TrainLoss 19.1336  TrainAcc 37.30%  ValLoss 18.9077  ValAcc 42.74%
# [LinearEval] Epoch 268/300  TrainLoss 21.5993  TrainAcc 36.63%  ValLoss 19.6159  ValAcc 36.12%
# [LinearEval] Epoch 269/300  TrainLoss 20.7416  TrainAcc 36.98%  ValLoss 15.4310  ValAcc 39.06%
# [LinearEval] Epoch 270/300  TrainLoss 22.2371  TrainAcc 37.10%  ValLoss 19.5688  ValAcc 39.31%
# [LinearEval] Epoch 271/300  TrainLoss 19.3360  TrainAcc 36.99%  ValLoss 17.4952  ValAcc 36.54%
# [LinearEval] Epoch 272/300  TrainLoss 17.3331  TrainAcc 37.72%  ValLoss 17.7007  ValAcc 41.41%
# [LinearEval] Epoch 273/300  TrainLoss 18.0300  TrainAcc 37.57%  ValLoss 21.1297  ValAcc 36.69%
# [LinearEval] Epoch 274/300  TrainLoss 22.5737  TrainAcc 36.25%  ValLoss 23.7546  ValAcc 37.43%
# [LinearEval] Epoch 275/300  TrainLoss 18.9705  TrainAcc 37.43%  ValLoss 15.9999  ValAcc 33.46%
# [LinearEval] Epoch 276/300  TrainLoss 22.4708  TrainAcc 36.28%  ValLoss 26.8138  ValAcc 38.35%
# [LinearEval] Epoch 277/300  TrainLoss 20.8080  TrainAcc 36.82%  ValLoss 17.6951  ValAcc 34.86%
# [LinearEval] Epoch 278/300  TrainLoss 20.7842  TrainAcc 37.16%  ValLoss 26.1438  ValAcc 35.75%
# [LinearEval] Epoch 279/300  TrainLoss 22.1960  TrainAcc 36.22%  ValLoss 20.6803  ValAcc 41.23%
# [LinearEval] Epoch 280/300  TrainLoss 21.2274  TrainAcc 37.01%  ValLoss 21.7584  ValAcc 34.84%
# [LinearEval] Epoch 281/300  TrainLoss 20.4734  TrainAcc 37.53%  ValLoss 18.2728  ValAcc 29.58%
# [LinearEval] Epoch 282/300  TrainLoss 17.8200  TrainAcc 37.89%  ValLoss 23.9663  ValAcc 39.23%
# [LinearEval] Epoch 283/300  TrainLoss 21.3465  TrainAcc 36.07%  ValLoss 22.1839  ValAcc 37.95%
# [LinearEval] Epoch 284/300  TrainLoss 21.2159  TrainAcc 37.40%  ValLoss 20.6138  ValAcc 41.83%
# [LinearEval] Epoch 285/300  TrainLoss 20.3813  TrainAcc 37.65%  ValLoss 16.4880  ValAcc 37.01%
# [LinearEval] Epoch 286/300  TrainLoss 21.0660  TrainAcc 36.01%  ValLoss 22.0310  ValAcc 36.10%
# [LinearEval] Epoch 287/300  TrainLoss 17.0479  TrainAcc 38.14%  ValLoss 11.7993  ValAcc 39.41%
# [LinearEval] Epoch 288/300  TrainLoss 23.0227  TrainAcc 36.67%  ValLoss 21.5579  ValAcc 41.21%
# [LinearEval] Epoch 289/300  TrainLoss 17.8633  TrainAcc 37.73%  ValLoss 29.4693  ValAcc 32.86%
# [LinearEval] Epoch 290/300  TrainLoss 21.3894  TrainAcc 37.06%  ValLoss 17.9599  ValAcc 36.54%
# [LinearEval] Epoch 291/300  TrainLoss 18.3329  TrainAcc 37.83%  ValLoss 15.2632  ValAcc 38.00%
# [LinearEval] Epoch 292/300  TrainLoss 20.1187  TrainAcc 37.14%  ValLoss 14.0918  ValAcc 39.53%
# [LinearEval] Epoch 293/300  TrainLoss 20.2610  TrainAcc 36.93%  ValLoss 30.4611  ValAcc 35.01%
# [LinearEval] Epoch 294/300  TrainLoss 20.5164  TrainAcc 37.40%  ValLoss 13.3750  ValAcc 44.57%
# [LinearEval] Epoch 295/300  TrainLoss 18.2550  TrainAcc 37.19%  ValLoss 28.9889  ValAcc 39.73%
# [LinearEval] Epoch 296/300  TrainLoss 20.4526  TrainAcc 36.97%  ValLoss 11.5981  ValAcc 40.00%
# [LinearEval] Epoch 297/300  TrainLoss 20.1520  TrainAcc 37.69%  ValLoss 19.1193  ValAcc 35.85%
# [LinearEval] Epoch 298/300  TrainLoss 21.8003  TrainAcc 36.99%  ValLoss 20.7819  ValAcc 33.41%
# [LinearEval] Epoch 299/300  TrainLoss 21.7233  TrainAcc 37.15%  ValLoss 27.7608  ValAcc 33.41%
# [LinearEval] Epoch 300/300  TrainLoss 19.7714  TrainAcc 37.20%  ValLoss 36.5939  ValAcc 27.21%

# %%
epochs = range(1, len(train_losses) + 1)

# Loss
plt.figure()
plt.plot(epochs, train_losses, label='Train loss')
plt.plot(epochs, val_losses, label='Val loss')
plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.title('Linear eval: loss')
plt.legend(); plt.tight_layout()
plt.show()

# Accuracy
plt.figure()
plt.plot(epochs, [a * 100 for a in train_accs], label='Train acc (%)')
plt.plot(epochs, [a * 100 for a in val_accs], label='Val acc (%)')
plt.xlabel('Epoch'); plt.ylabel('Accuracy (%)'); plt.title('Linear eval: accuracy')
plt.legend(); plt.tight_layout()
plt.show()

# Best epoch summary
best_epoch = int(np.argmin(val_losses)) + 1
print(f"Best epoch (min val loss): {best_epoch}  |  Val acc: {val_accs[best_epoch-1]*100:.2f}%")
# Out:
# Best epoch (min val loss): 180  |  Val acc: 38.84%

# %% [markdown]
# # **Evaluate on test set**

# %%
# Final Test Set Evaluation
model.eval()
test_loss, correct, total = 0.0, 0, 0

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        test_loss += loss.item()
        preds = outputs.argmax(dim=1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

test_loss /= len(test_loader)
test_acc = correct / total
print(f"\nFinal Test Accuracy: {test_acc:.2%}, Test Loss: {test_loss:.4f}")
# Out:
# Final Test Accuracy: 28.27%, Test Loss: 37.4260
