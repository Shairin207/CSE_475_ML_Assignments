# %% [markdown]
# # **Import Libraries**

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision.datasets import ImageFolder
from torchvision import transforms
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader, random_split, Dataset
import matplotlib.pyplot as plt
from tqdm import tqdm
import os
import copy
import numpy as np

# %% [markdown]
# # **Set Up**

# %%
# Device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Dataset Path
dataset_path = "/kaggle/input/eurosat-dataset/EuroSAT"

# %%
transform_classifier = transforms.Compose([
    transforms.Resize(72),
    transforms.CenterCrop(64),
    transforms.ToTensor(),
])

# %%
# Load dataset
full_dataset = datasets.ImageFolder(dataset_path, transform=transform_classifier)
num_classes = len(full_dataset.classes)

# Train - Test - Validation
train_size = int(0.7 * len(full_dataset))
val_size = int(0.15 * len(full_dataset))
test_size = len(full_dataset) - train_size - val_size

train_set, val_set, test_set = random_split(full_dataset, [train_size, val_size, test_size])

train_loader = DataLoader(train_set, batch_size=64, shuffle=True, num_workers=2)
val_loader = DataLoader(val_set, batch_size=64, shuffle=False, num_workers=2)
test_loader = DataLoader(test_set, batch_size=64, shuffle=False, num_workers=2)

# %% [markdown]
# # **Load MoCo Encoder**

# %%
class EncoderWrapper(nn.Module):
    def __init__(self, out_dim=128, checkpoint_path=None):
        super().__init__()
        backbone = models.resnet50(weights=None)   # replaces deprecated pretrained=False
        dim_backbone = backbone.fc.in_features
        backbone.fc = nn.Identity()                # backbone outputs 2048-d features
        self.backbone = backbone
        self.encoder = self.backbone               # alias so .encoder works

        # projection head for contrastive pretraining
        self.proj_head = nn.Sequential(
            nn.Linear(dim_backbone, 512),
            nn.ReLU(inplace=True),
            nn.Linear(512, out_dim)
        )

        if checkpoint_path:
            self.load_state_dict(torch.load(checkpoint_path, map_location="cpu"))

    def forward(self, x, proj=True):
        h = self.backbone(x)        # representation (e.g., 2048-d)
        if proj:
            return self.proj_head(h)  # 128-d for contrastive
        return h                      # backbone features for linear eval


# Instantiate and save encoder (inner backbone weights)
moco_encoder = EncoderWrapper(out_dim=128)

# %% [markdown]
# # **MoCo Momentum Encoder + Queue**

# %%
# Momentum encoder setup
query_encoder = EncoderWrapper().to(device)
key_encoder = EncoderWrapper().to(device)

key_encoder.load_state_dict(query_encoder.state_dict())
for param in key_encoder.parameters():
    param.requires_grad = False  # Freeze key encoder

# Momentum update
def momentum_update(query_encoder, key_encoder, m=0.999):
    for param_q, param_k in zip(query_encoder.parameters(), key_encoder.parameters()):
        param_k.data = param_k.data * m + param_q.data * (1. - m)

K = 4096             # queue size
proj_dim = 128  # must match EncoderWrapper(out_dim)
queue = F.normalize(torch.randn(proj_dim, K, device=device), dim=0)  # [128, K]
queue_ptr = 0

@torch.no_grad()
def dequeue_and_enqueue(keys):
    # keys: [N, proj_dim]
    global queue, queue_ptr
    bsz = keys.shape[0]
    ptr = queue_ptr
    end = ptr + bsz
    if end <= K:
        queue[:, ptr:end] = keys.T
    else:
        first = K - ptr
        queue[:, ptr:] = keys[:first].T
        queue[:, :bsz-first] = keys[first:].T
    queue_ptr = (ptr + bsz) % K

# %% [markdown]
# # **MoCo Pretraining Loop**

# %%
# MoCo v2-style augments for EuroSAT (64x64)
moco_transform = transforms.Compose([
    transforms.RandomResizedCrop(64, scale=(0.2, 1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomApply([transforms.ColorJitter(0.4, 0.4, 0.4, 0.1)], p=0.8),
    transforms.RandomGrayscale(p=0.2),
    transforms.RandomApply([transforms.GaussianBlur(kernel_size=9, sigma=(0.1, 2.0))], p=0.5),
    transforms.ToTensor(),
    # Optional but recommended if you’ll ever swap to ImageNet-pretrained encoders:
    # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

class ContrastiveDataset(Dataset):
    def __init__(self, base_dataset):
        self.dataset = base_dataset
    def __getitem__(self, idx):
        x, _ = self.dataset[idx]
        return moco_transform(x), moco_transform(x)
    def __len__(self):
        return len(self.dataset)

# %%
# Path from EuroSAT dataset
data_dir = "/kaggle/input/eurosat-dataset/EuroSAT"  

# Load base dataset (without transform)
base_dataset = ImageFolder(data_dir)

# Wrap with contrastive dataset
contrastive_dataset = ContrastiveDataset(base_dataset)

# DataLoader
contrastive_loader = DataLoader(contrastive_dataset, batch_size=64, shuffle=True, num_workers=2)

# %%
save_path = "/kaggle/working/best_moco_encoder.pth"
best_loss = float('inf')
moco_losses = []  # Track pretraining loss
temperature = 0.07
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(query_encoder.parameters(), lr=3e-4, weight_decay=1e-4)

for epoch in range(100):
    query_encoder.train()
    key_encoder.eval()

    running = 0.0
    for x_q, x_k in contrastive_loader:
        x_q, x_k = x_q.to(device), x_k.to(device)

        # 1) momentum update before key forward
        momentum_update(query_encoder, key_encoder, m=0.999)

        # 2) forward
        q = query_encoder(x_q, proj=True)                 # [N,128]
        with torch.no_grad():
            k = key_encoder(x_k, proj=True)               # [N,128]

        # 3) L2-normalize
        q = F.normalize(q, dim=1)
        k = F.normalize(k, dim=1)
        
        # 4) logits and loss
        l_pos = torch.einsum('nc,nc->n', q, k).unsqueeze(-1)      # [N, 1]
        l_neg = torch.einsum('nc,ck->nk', q, queue)               # [N, K]
        logits = torch.cat([l_pos, l_neg], dim=1) / temperature   # [N, 1+K]
        labels = torch.zeros(logits.size(0), dtype=torch.long, device=device)
        
        loss = criterion(logits, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        running += loss.item()
        
        # 5) enqueue the current keys
        with torch.no_grad():
            dequeue_and_enqueue(k)

    avg_loss = running / len(contrastive_loader)
    moco_losses.append(avg_loss)
    print(f"Epoch {epoch+1}: loss={avg_loss:.4f}")

    if avg_loss < best_loss:
        best_loss = avg_loss
        torch.save(query_encoder.state_dict(), save_path)
        print(f" Saved best at epoch {epoch+1}")

np.savetxt("/kaggle/working/moco_pretraining_loss.txt", np.array(moco_losses))
# Out:
# Epoch 1: loss=6.4767
#  Saved best at epoch 1
# Epoch 2: loss=7.3811
# Epoch 3: loss=7.4256
# Epoch 4: loss=6.7105
# Epoch 5: loss=6.2615
#  Saved best at epoch 5
# Epoch 6: loss=6.7353
# Epoch 7: loss=6.8286
# Epoch 8: loss=7.0570
# Epoch 9: loss=7.3623
# Epoch 10: loss=7.5117
# Epoch 11: loss=7.6918
# Epoch 12: loss=7.8976
# Epoch 13: loss=8.0510
# Epoch 14: loss=8.0183
# Epoch 15: loss=7.8015
# Epoch 16: loss=7.6162
# Epoch 17: loss=7.7528
# Epoch 18: loss=7.8380
# Epoch 19: loss=7.6328
# Epoch 20: loss=7.6052
# Epoch 21: loss=7.2527
# Epoch 22: loss=7.2684
# Epoch 23: loss=7.2475
# Epoch 24: loss=7.1637
# Epoch 25: loss=6.9476
# Epoch 26: loss=7.0146
# Epoch 27: loss=6.9995
# Epoch 28: loss=6.9013
# Epoch 29: loss=7.1803
# Epoch 30: loss=7.0635
# Epoch 31: loss=7.0021
# Epoch 32: loss=7.1275
# Epoch 33: loss=7.0290
# Epoch 34: loss=7.0430
# Epoch 35: loss=7.0089
# Epoch 36: loss=7.0366
# Epoch 37: loss=7.1123
# Epoch 38: loss=6.9806
# Epoch 39: loss=7.0160
# Epoch 40: loss=7.1009
# Epoch 41: loss=7.1628
# Epoch 42: loss=7.1657
# Epoch 43: loss=7.1080
# Epoch 44: loss=7.0605
# Epoch 45: loss=7.1216
# Epoch 46: loss=7.1721
# Epoch 47: loss=7.0967
# Epoch 48: loss=7.0148
# Epoch 49: loss=7.0801
# Epoch 50: loss=7.1111
# Epoch 51: loss=7.1367
# Epoch 52: loss=7.1338
# Epoch 53: loss=7.1095
# Epoch 54: loss=7.1401
# Epoch 55: loss=7.1385
# Epoch 56: loss=7.1183
# Epoch 57: loss=7.1370
# Epoch 58: loss=7.1715
# Epoch 59: loss=7.1476
# Epoch 60: loss=7.1119
# Epoch 61: loss=7.0896
# Epoch 62: loss=7.1410
# Epoch 63: loss=7.1835
# Epoch 64: loss=7.1791
# Epoch 65: loss=7.1341
# Epoch 66: loss=7.1307
# Epoch 67: loss=7.1462
# Epoch 68: loss=7.1596
# Epoch 69: loss=7.1628
# Epoch 70: loss=7.1211
# Epoch 71: loss=7.0928
# Epoch 72: loss=7.1246
# Epoch 73: loss=7.1776
# Epoch 74: loss=7.1548
# Epoch 75: loss=7.1202
# Epoch 76: loss=7.1253
# Epoch 77: loss=7.1290
# Epoch 78: loss=7.1375
# Epoch 79: loss=7.1240
# Epoch 80: loss=7.1346
# Epoch 81: loss=7.1379
# Epoch 82: loss=7.1449
# Epoch 83: loss=7.1369
# Epoch 84: loss=7.1230
# Epoch 85: loss=7.1250
# Epoch 86: loss=7.1380
# Epoch 87: loss=7.1524
# Epoch 88: loss=7.1047
# Epoch 89: loss=7.1065
# Epoch 90: loss=7.1454
# Epoch 91: loss=7.1674
# Epoch 92: loss=7.1216
# Epoch 93: loss=7.1231
# Epoch 94: loss=7.1404
# Epoch 95: loss=7.1201
# Epoch 96: loss=7.1277
# Epoch 97: loss=7.1299
# Epoch 98: loss=7.1310
# Epoch 99: loss=7.1091
# Epoch 100: loss=7.1248

# %%
# Plot Pertraining Loss
moco_losses = np.loadtxt("/kaggle/working/moco_pretraining_loss.txt")

plt.figure(figsize=(8, 4))
plt.plot(range(1, len(moco_losses) + 1), moco_losses, marker='o', linestyle='-', color='purple')
plt.title("MoCo Pretraining Loss per Epoch")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Linear Classifier with Frozen MoCo Encoder**

# %%
enc = EncoderWrapper(out_dim=128)
enc.load_state_dict(torch.load("/kaggle/working/best_moco_encoder.pth", map_location=device))
enc.to(device)

class LinearEvalClassifier(nn.Module):
    def __init__(self, encoder, feat_dim=2048, num_classes=10):
        super().__init__()
        # freeze backbone
        for p in encoder.parameters():
            p.requires_grad = False
        self.encoder = encoder
        self.fc = nn.Linear(feat_dim, num_classes)

    def forward(self, x):
        with torch.no_grad():
            feats = self.encoder(x, proj=False)  # backbone features, not projector
        return self.fc(feats)

model = LinearEvalClassifier(enc, feat_dim=2048, num_classes=num_classes).to(device)
optimizer = torch.optim.SGD(model.fc.parameters(), lr=0.1, momentum=0.9, weight_decay=0.0)
criterion = nn.CrossEntropyLoss()


train_losses, val_losses = [], []
train_accs,  val_accs  = [],  []

best_val_loss = float("inf")

epochs = 100

for epoch in range(epochs):
    # Train
    model.train()
    running_loss, correct, total = 0.0, 0, 0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        logits = model(images)
        loss = criterion(logits, labels)

        optimizer.zero_grad(set_to_none=True)
        loss.backward()
        optimizer.step()

        bs = labels.size(0)
        running_loss += loss.item() * bs
        correct += (logits.argmax(1) == labels).sum().item()
        total += bs

    train_losses.append(running_loss / max(1, total))
    train_accs.append(correct / max(1, total))

    # Validation
    model.eval()
    val_running_loss, vcorrect, vtotal = 0.0, 0, 0
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            vlogits = model(images)
            vloss = criterion(vlogits, labels)

            bs = labels.size(0)
            val_running_loss += vloss.item() * bs
            vcorrect += (vlogits.argmax(1) == labels).sum().item()
            vtotal += bs

    val_loss = val_running_loss / max(1, vtotal)
    val_acc  = vcorrect / max(1, vtotal)
    val_losses.append(val_loss)
    val_accs.append(val_acc)

    print(f"[LinearEval] Epoch {epoch+1}/{epochs}  "
          f"TrainLoss {train_losses[-1]:.4f}  TrainAcc {train_accs[-1]*100:.2f}%  "
          f"ValLoss {val_loss:.4f}  ValAcc {val_acc*100:.2f}%")

    
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model.state_dict(), "/kaggle/working/best_classifier.pth")
        print("  Saved best linear classifier")
# Out:
# [LinearEval] Epoch 1/100  TrainLoss 27.9248  TrainAcc 25.92%  ValLoss 28.7124  ValAcc 27.16%
#   Saved best linear classifier
# [LinearEval] Epoch 2/100  TrainLoss 26.9522  TrainAcc 26.88%  ValLoss 22.9278  ValAcc 21.56%
#   Saved best linear classifier
# [LinearEval] Epoch 3/100  TrainLoss 23.8804  TrainAcc 27.49%  ValLoss 34.3311  ValAcc 25.26%
# [LinearEval] Epoch 4/100  TrainLoss 24.9430  TrainAcc 28.35%  ValLoss 27.1201  ValAcc 33.83%
# [LinearEval] Epoch 5/100  TrainLoss 24.3205  TrainAcc 28.13%  ValLoss 23.8477  ValAcc 25.73%
# [LinearEval] Epoch 6/100  TrainLoss 26.7335  TrainAcc 28.71%  ValLoss 14.9751  ValAcc 27.06%
#   Saved best linear classifier
# [LinearEval] Epoch 7/100  TrainLoss 20.7292  TrainAcc 30.49%  ValLoss 25.1469  ValAcc 27.11%
# [LinearEval] Epoch 8/100  TrainLoss 22.1494  TrainAcc 29.75%  ValLoss 25.7297  ValAcc 23.95%
# [LinearEval] Epoch 9/100  TrainLoss 24.9337  TrainAcc 29.53%  ValLoss 36.0812  ValAcc 26.89%
# [LinearEval] Epoch 10/100  TrainLoss 22.2867  TrainAcc 30.01%  ValLoss 33.0562  ValAcc 22.94%
# [LinearEval] Epoch 11/100  TrainLoss 24.2946  TrainAcc 29.78%  ValLoss 20.3384  ValAcc 34.69%
# [LinearEval] Epoch 12/100  TrainLoss 20.9759  TrainAcc 30.63%  ValLoss 23.6078  ValAcc 27.41%
# [LinearEval] Epoch 13/100  TrainLoss 23.8285  TrainAcc 30.19%  ValLoss 25.6199  ValAcc 28.15%
# [LinearEval] Epoch 14/100  TrainLoss 23.5810  TrainAcc 29.87%  ValLoss 15.3226  ValAcc 37.48%
# [LinearEval] Epoch 15/100  TrainLoss 24.2342  TrainAcc 30.73%  ValLoss 26.7098  ValAcc 23.09%
# [LinearEval] Epoch 16/100  TrainLoss 23.2334  TrainAcc 30.87%  ValLoss 22.3372  ValAcc 29.43%
# [LinearEval] Epoch 17/100  TrainLoss 23.5656  TrainAcc 31.18%  ValLoss 19.5058  ValAcc 38.40%
# [LinearEval] Epoch 18/100  TrainLoss 20.9492  TrainAcc 31.30%  ValLoss 21.8796  ValAcc 27.19%
# [LinearEval] Epoch 19/100  TrainLoss 22.8636  TrainAcc 30.81%  ValLoss 31.5643  ValAcc 34.91%
# [LinearEval] Epoch 20/100  TrainLoss 22.8164  TrainAcc 30.95%  ValLoss 17.6816  ValAcc 28.77%
# [LinearEval] Epoch 21/100  TrainLoss 22.1937  TrainAcc 31.52%  ValLoss 35.1884  ValAcc 22.91%
# [LinearEval] Epoch 22/100  TrainLoss 24.5362  TrainAcc 32.01%  ValLoss 19.5021  ValAcc 40.86%
# [LinearEval] Epoch 23/100  TrainLoss 23.4272  TrainAcc 31.05%  ValLoss 18.2798  ValAcc 37.51%
# [LinearEval] Epoch 24/100  TrainLoss 20.2693  TrainAcc 32.63%  ValLoss 28.5920  ValAcc 35.21%
# [LinearEval] Epoch 25/100  TrainLoss 19.6098  TrainAcc 32.79%  ValLoss 19.9892  ValAcc 36.81%
# [LinearEval] Epoch 26/100  TrainLoss 21.8170  TrainAcc 32.39%  ValLoss 19.6263  ValAcc 29.16%
# [LinearEval] Epoch 27/100  TrainLoss 25.2340  TrainAcc 31.19%  ValLoss 15.4613  ValAcc 36.47%
# [LinearEval] Epoch 28/100  TrainLoss 21.2448  TrainAcc 32.34%  ValLoss 19.1252  ValAcc 31.26%
# [LinearEval] Epoch 29/100  TrainLoss 23.3262  TrainAcc 31.74%  ValLoss 20.1370  ValAcc 32.05%
# [LinearEval] Epoch 30/100  TrainLoss 21.8060  TrainAcc 32.15%  ValLoss 17.7933  ValAcc 31.85%
# [LinearEval] Epoch 31/100  TrainLoss 21.0915  TrainAcc 32.31%  ValLoss 23.8740  ValAcc 38.67%
# [LinearEval] Epoch 32/100  TrainLoss 19.6958  TrainAcc 33.44%  ValLoss 24.9353  ValAcc 34.77%
# [LinearEval] Epoch 33/100  TrainLoss 21.7327  TrainAcc 31.84%  ValLoss 24.8681  ValAcc 29.85%
# [LinearEval] Epoch 34/100  TrainLoss 22.6287  TrainAcc 31.96%  ValLoss 14.7459  ValAcc 34.05%
#   Saved best linear classifier
# [LinearEval] Epoch 35/100  TrainLoss 21.7660  TrainAcc 32.39%  ValLoss 40.1156  ValAcc 32.89%
# [LinearEval] Epoch 36/100  TrainLoss 24.6633  TrainAcc 32.15%  ValLoss 21.0448  ValAcc 35.14%
# [LinearEval] Epoch 37/100  TrainLoss 21.2116  TrainAcc 33.22%  ValLoss 21.0967  ValAcc 31.58%
# [LinearEval] Epoch 38/100  TrainLoss 21.4398  TrainAcc 33.22%  ValLoss 38.2954  ValAcc 29.95%
# [LinearEval] Epoch 39/100  TrainLoss 22.8641  TrainAcc 32.36%  ValLoss 14.4510  ValAcc 36.47%
#   Saved best linear classifier
# [LinearEval] Epoch 40/100  TrainLoss 18.2293  TrainAcc 33.90%  ValLoss 17.6575  ValAcc 33.85%
# [LinearEval] Epoch 41/100  TrainLoss 21.1014  TrainAcc 33.11%  ValLoss 13.1426  ValAcc 42.49%
#   Saved best linear classifier
# [LinearEval] Epoch 42/100  TrainLoss 19.0984  TrainAcc 33.46%  ValLoss 16.6426  ValAcc 40.00%
# [LinearEval] Epoch 43/100  TrainLoss 20.2222  TrainAcc 33.36%  ValLoss 22.5918  ValAcc 34.67%
# [LinearEval] Epoch 44/100  TrainLoss 20.7850  TrainAcc 32.79%  ValLoss 23.7746  ValAcc 29.09%
# [LinearEval] Epoch 45/100  TrainLoss 21.8039  TrainAcc 32.58%  ValLoss 32.7744  ValAcc 28.40%
# [LinearEval] Epoch 46/100  TrainLoss 21.1780  TrainAcc 33.69%  ValLoss 31.6263  ValAcc 28.32%
# [LinearEval] Epoch 47/100  TrainLoss 21.5999  TrainAcc 32.56%  ValLoss 12.4169  ValAcc 33.95%
#   Saved best linear classifier
# [LinearEval] Epoch 48/100  TrainLoss 24.6285  TrainAcc 32.89%  ValLoss 27.0944  ValAcc 34.59%
# [LinearEval] Epoch 49/100  TrainLoss 20.8857  TrainAcc 32.78%  ValLoss 19.3494  ValAcc 28.37%
# [LinearEval] Epoch 50/100  TrainLoss 19.8214  TrainAcc 33.83%  ValLoss 17.4678  ValAcc 37.68%
# [LinearEval] Epoch 51/100  TrainLoss 20.6503  TrainAcc 33.53%  ValLoss 18.8088  ValAcc 32.25%
# [LinearEval] Epoch 52/100  TrainLoss 21.3012  TrainAcc 33.16%  ValLoss 23.3580  ValAcc 40.81%
# [LinearEval] Epoch 53/100  TrainLoss 23.1699  TrainAcc 33.12%  ValLoss 22.1686  ValAcc 38.32%
# [LinearEval] Epoch 54/100  TrainLoss 21.4314  TrainAcc 33.80%  ValLoss 27.5639  ValAcc 39.46%
# [LinearEval] Epoch 55/100  TrainLoss 22.9730  TrainAcc 33.30%  ValLoss 25.1172  ValAcc 34.59%
# [LinearEval] Epoch 56/100  TrainLoss 23.3306  TrainAcc 33.40%  ValLoss 18.0475  ValAcc 34.54%
# [LinearEval] Epoch 57/100  TrainLoss 24.1583  TrainAcc 33.04%  ValLoss 36.4008  ValAcc 28.42%
# [LinearEval] Epoch 58/100  TrainLoss 22.4446  TrainAcc 33.93%  ValLoss 22.0369  ValAcc 41.26%
# [LinearEval] Epoch 59/100  TrainLoss 22.0565  TrainAcc 33.85%  ValLoss 16.8875  ValAcc 30.74%
# [LinearEval] Epoch 60/100  TrainLoss 23.1759  TrainAcc 32.82%  ValLoss 19.0213  ValAcc 31.11%
# [LinearEval] Epoch 61/100  TrainLoss 20.3220  TrainAcc 34.66%  ValLoss 23.4795  ValAcc 30.42%
# [LinearEval] Epoch 62/100  TrainLoss 21.0951  TrainAcc 33.53%  ValLoss 14.9665  ValAcc 32.52%
# [LinearEval] Epoch 63/100  TrainLoss 18.5776  TrainAcc 34.41%  ValLoss 15.8768  ValAcc 26.00%
# [LinearEval] Epoch 64/100  TrainLoss 21.9375  TrainAcc 34.17%  ValLoss 13.8214  ValAcc 42.17%
# [LinearEval] Epoch 65/100  TrainLoss 22.8064  TrainAcc 34.13%  ValLoss 14.0705  ValAcc 37.83%
# [LinearEval] Epoch 66/100  TrainLoss 21.6598  TrainAcc 34.66%  ValLoss 23.7875  ValAcc 33.56%
# [LinearEval] Epoch 67/100  TrainLoss 19.8472  TrainAcc 34.28%  ValLoss 22.9577  ValAcc 34.42%
# [LinearEval] Epoch 68/100  TrainLoss 21.6480  TrainAcc 33.38%  ValLoss 37.8987  ValAcc 27.56%
# [LinearEval] Epoch 69/100  TrainLoss 25.0203  TrainAcc 33.40%  ValLoss 24.0330  ValAcc 35.31%
# [LinearEval] Epoch 70/100  TrainLoss 19.7429  TrainAcc 34.61%  ValLoss 19.0542  ValAcc 39.98%
# [LinearEval] Epoch 71/100  TrainLoss 20.4209  TrainAcc 34.86%  ValLoss 19.1636  ValAcc 37.06%
# [LinearEval] Epoch 72/100  TrainLoss 18.6442  TrainAcc 35.39%  ValLoss 15.2304  ValAcc 36.86%
# [LinearEval] Epoch 73/100  TrainLoss 20.2011  TrainAcc 34.12%  ValLoss 26.8403  ValAcc 35.11%
# [LinearEval] Epoch 74/100  TrainLoss 22.2335  TrainAcc 34.59%  ValLoss 24.2066  ValAcc 38.47%
# [LinearEval] Epoch 75/100  TrainLoss 22.1419  TrainAcc 33.94%  ValLoss 20.1753  ValAcc 32.57%
# [LinearEval] Epoch 76/100  TrainLoss 26.3211  TrainAcc 33.17%  ValLoss 23.1150  ValAcc 30.91%
# [LinearEval] Epoch 77/100  TrainLoss 23.8134  TrainAcc 33.75%  ValLoss 24.0371  ValAcc 36.35%
# [LinearEval] Epoch 78/100  TrainLoss 21.4242  TrainAcc 34.31%  ValLoss 15.2977  ValAcc 34.40%
# [LinearEval] Epoch 79/100  TrainLoss 21.4922  TrainAcc 34.56%  ValLoss 15.7754  ValAcc 37.11%
# [LinearEval] Epoch 80/100  TrainLoss 20.0241  TrainAcc 34.51%  ValLoss 15.4833  ValAcc 36.67%
# [LinearEval] Epoch 81/100  TrainLoss 20.5735  TrainAcc 34.66%  ValLoss 16.2661  ValAcc 33.36%
# [LinearEval] Epoch 82/100  TrainLoss 20.1358  TrainAcc 34.31%  ValLoss 28.1671  ValAcc 28.96%
# [LinearEval] Epoch 83/100  TrainLoss 18.1240  TrainAcc 34.93%  ValLoss 27.4087  ValAcc 30.27%
# [LinearEval] Epoch 84/100  TrainLoss 21.9457  TrainAcc 35.04%  ValLoss 18.3244  ValAcc 33.56%
# [LinearEval] Epoch 85/100  TrainLoss 22.2356  TrainAcc 33.67%  ValLoss 17.0921  ValAcc 37.46%
# [LinearEval] Epoch 86/100  TrainLoss 20.2300  TrainAcc 34.47%  ValLoss 14.9913  ValAcc 37.85%
# [LinearEval] Epoch 87/100  TrainLoss 21.1093  TrainAcc 34.60%  ValLoss 53.5433  ValAcc 37.41%
# [LinearEval] Epoch 88/100  TrainLoss 21.2047  TrainAcc 34.31%  ValLoss 19.0276  ValAcc 34.07%
# [LinearEval] Epoch 89/100  TrainLoss 19.1793  TrainAcc 34.64%  ValLoss 13.8979  ValAcc 42.72%
# [LinearEval] Epoch 90/100  TrainLoss 20.4200  TrainAcc 35.10%  ValLoss 25.8566  ValAcc 38.67%
# [LinearEval] Epoch 91/100  TrainLoss 22.9960  TrainAcc 34.56%  ValLoss 14.8473  ValAcc 29.73%
# [LinearEval] Epoch 92/100  TrainLoss 19.1968  TrainAcc 35.31%  ValLoss 17.2300  ValAcc 34.96%
# [LinearEval] Epoch 93/100  TrainLoss 20.1750  TrainAcc 34.47%  ValLoss 16.4514  ValAcc 43.75%
# [LinearEval] Epoch 94/100  TrainLoss 19.6828  TrainAcc 35.12%  ValLoss 18.0602  ValAcc 38.35%
# [LinearEval] Epoch 95/100  TrainLoss 20.7265  TrainAcc 34.38%  ValLoss 28.5245  ValAcc 38.40%
# [LinearEval] Epoch 96/100  TrainLoss 18.2487  TrainAcc 35.47%  ValLoss 18.6084  ValAcc 38.40%
# [LinearEval] Epoch 97/100  TrainLoss 20.5951  TrainAcc 34.55%  ValLoss 19.3195  ValAcc 32.00%
# [LinearEval] Epoch 98/100  TrainLoss 17.7840  TrainAcc 35.69%  ValLoss 32.5881  ValAcc 32.72%
# [LinearEval] Epoch 99/100  TrainLoss 18.0131  TrainAcc 35.53%  ValLoss 16.8966  ValAcc 43.38%
# [LinearEval] Epoch 100/100  TrainLoss 19.2032  TrainAcc 34.99%  ValLoss 12.1922  ValAcc 41.83%
#   Saved best linear classifier

# %%
epochs = range(1, len(train_losses) + 1)

# Loss
plt.figure()
plt.plot(epochs, train_losses, label='Train loss')
plt.plot(epochs, val_losses, label='Val loss')
plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.title('Linear eval: loss')
plt.legend(); plt.tight_layout()
plt.show()

# Accuracy
plt.figure()
plt.plot(epochs, [a * 100 for a in train_accs], label='Train acc (%)')
plt.plot(epochs, [a * 100 for a in val_accs], label='Val acc (%)')
plt.xlabel('Epoch'); plt.ylabel('Accuracy (%)'); plt.title('Linear eval: accuracy')
plt.legend(); plt.tight_layout()
plt.show()

# Best epoch summary
best_epoch = int(np.argmin(val_losses)) + 1
print(f"Best epoch (min val loss): {best_epoch}  |  Val acc: {val_accs[best_epoch-1]*100:.2f}%")
# Out:
# Best epoch (min val loss): 100  |  Val acc: 41.83%

# %% [markdown]
# # **Evaluate on test set**

# %%
# Final Test Set Evaluation
model.eval()
test_loss, correct, total = 0.0, 0, 0

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        test_loss += loss.item()
        preds = outputs.argmax(dim=1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

test_loss /= len(test_loader)
test_acc = correct / total
print(f"\nFinal Test Accuracy: {test_acc:.2%}, Test Loss: {test_loss:.4f}")
# Out:
# Final Test Accuracy: 38.89%, Test Loss: 12.5295
